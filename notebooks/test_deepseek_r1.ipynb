# %%
import sys
from typing import Dict
import json
sys.path.append("..")

from utils.llm import DeepSeekR1

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = DeepSeekR1(base_url="https://api.deepseek.com", model='deepseek-chat')

# %%
client.generate("Is 1e9+7 a prime?")
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client.generate("Is 1e9+7 a prime?")
#
# File ~/Desktop/NEU/Capstone/RAG-LLM-Metric/evaluator/llm.py:55, in DeepSeekR1.generate(self, prompt)
#      50 """Execute synchronous LLM call"""
#      51 messages = [
#      52     {"role": "user", "content": f"{prompt} \n\nAssistant: <think>\n"}
#      53 ]
# ---> 55 completion = self.client.chat.completions.create(
#      56     model=self.model,
#      57     messages=messages,
#      58     **self.params
#      59 )
#      60 match  = re.search(r'</think>\n\n(.*)', completion.choices[0].message.content, re.DOTALL)
#      61 return match.group(1)
#
# File ~/Desktop/NEU/Capstone/RAG-LLM-Metric/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...
